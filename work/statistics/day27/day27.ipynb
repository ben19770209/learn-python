# %% [markdown]
# ## 作業:
# 今天學到2種分配，包含，
# 離散均勻分配( Discrete Uniform Distribution )
# 伯努利分配( Bernoulli Distribution )
#
# 今天我們透過作業中的問題，回想今天的內容吧!

# %% [markdown]
# ### 丟一個銅板，丟了100次，出現正面 50 次的機率有多大。
# (提示: 先想是哪一種分配，然後透過 python 語法進行計算)

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics

# %%
# 1.定義二項分佈的基本資訊
p = 0.5 # 事件A 機率 0.4
n = 100  # 重複實驗5次,
r = np.arange(0,2) # 可以出現的範圍為 0,1,2,...,5-->6種可能出現的結果
r
# Out:
# array([0, 1])

# %%
# 2.計算二項分佈的概率質量分佈 (probability mass function)
# 之所以稱為質量，是因為離散的點
# P(X=x) --> 是機率
probs = stats.binom.pmf(r, n, p)
probs
# Out:
# array([7.88860905e-31, 7.88860905e-29])

# %%
plt.bar(r, probs)
plt.ylabel('P(X=x)')
plt.xlabel('x')
plt.title('binomial(n={},p={})'.format(n, p))
plt.show()

# %%
# 3.計算二項分佈的累積機率 (cumulative density function)，pmf 的累加
# 之所以稱為質量，是因為離散的點，預設體積（即寬度）為1
# P(X=x) --> 是機率
cumsum_probs = stats.binom.cdf(r, n, p)
#array([ 0.07776, 0.2592 , 0.3456 , 0.2304 , 0.0768 , 0.01024])
plt.show()
plt.ylabel('P(X<=x)')
plt.xlabel('x')
plt.title('binomial(n={},p={})'.format(n, p))
plt.plot(r, cumsum_probs)
plt.show()

# %%
# 5.產生符合二項分佈的隨機樣本點 (random sample)
X = stats.binom.rvs(n,p,size=100)
#array([2, 3, 1, 2, 2, 2, 1, 2, 2, 3, 3, 0, 1, 1, 1, 2, 3, 4, 0, 3])
print(X)
plt.hist(X)
plt.show()
#試試看，，每一次的結果一樣嗎?
# Out:
# [49 50 52 56 52 59 53 48 52 51 52 55 42 50 54 48 50 55 54 51 47 43 57 44
#  51 68 57 47 45 53 50 47 49 57 52 51 54 52 49 43 50 48 53 52 53 42 54 48
#  56 51 56 54 45 47 49 46 40 48 55 49 51 48 55 50 52 47 53 47 53 61 46 47
#  42 57 49 50 48 53 52 55 60 56 42 49 50 50 44 51 49 55 55 57 47 41 49 59
#  47 48 51 54]
